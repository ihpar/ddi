# %%
import pandas as pd

# %%
df = pd.read_csv("/content/filmler_clean.csv")

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  arabesk unutmak kadın ses o Bergen inmek hayat...
# 1  çocuk film kirpi Sonic film deva halka o yapım...
# 2  Karanlık büyü Gellert Grindelwald büyü Dünya k...
# 3  Aykut enişte 2 sevmek kadın ev arife kendi tür...
# 4  Morbius hastalık deva bulmak Çalışır bambaşka ...

# %%
clean = df["clean"]

# %%
len(clean)
# Out:
# 5261

# %%
word2idx = {}
idx2word = {}

# %%
i = 0
for cell in clean:
    words = cell.split()
    for word in words:
        if word in word2idx:
            continue
        word2idx[word] = i
        idx2word[i] = word
        i += 1

# %%
word2idx
# Out:
# {'arabesk': 0,
#  'unutmak': 1,
#  'kadın': 2,
#  'ses': 3,
#  'o': 4,
#  'Bergen': 5,
#  'inmek': 6,
#  'hayat': 7,
#  'anlatmak': 8,
#  'film': 9,
#  'olmak': 10,
#  'bilmek': 11,
#  'belgi': 12,
#  'Ankara': 13,
#  'dan': 14,
#  'ada': 15,
#  'ora': 16,
#  'yaşamak': 17,
#  'aşk': 18,
#  'ardından': 19,
#  'ebediyet': 20,
#  'uzanmak': 21,
#  'öykü': 22,
#  '1959': 23,
#  'yıl': 24,
#  'Mersin': 25,
#  'yemek': 26,
#  'çocuklu': 27,
#  'bir': 28,
#  'aile': 29,
#  'küçük': 30,
#  'çocuk': 31,
#  'Dünya': 32,
#  'gelir': 33,
#  'Anne': 34,
#  'baba': 35,
#  'boşanma': 36,
#  'kök': 37,
#  'biçim': 38,
#  'değişmek': 39,
#  'başka': 40,
#  'kimse': 41,
#  'yok': 42,
#  'yoksun': 43,
#  'iç': 44,
#  'dermek': 45,
#  'boşluk': 46,
#  'açar': 47,
#  'ötmek': 48,
#  'yan': 49,
#  'konservatuar': 50,
#  'girmek': 51,
#  'başarı': 52,
#  'katmer': 53,
#  'gelmek': 54,
#  'umut': 55,
#  'ilk': 56,
#  'Abdullah': 57,
#  'tan': 58,
#  'ayırmak': 59,
#  'yar': 60,
#  'almak': 61,
#  'ama': 62,
#  'büyük': 63,
#  'güç': 64,
#  'yetenek': 65,
#  'nın': 66,
#  'prestij': 67,
#  'mekân': 68,
#  'Feyman': 69,
#  'Kulüp': 70,
#  'Te': 71,
#  'keşfetmek': 72,
#  'Birlik': 73,
#  'parlamak': 74,
#  'Genç': 75,
#  'yıldız': 76,
#  'E': 77,
#  'dönüşmek': 78,
#  'ancak': 79,
#  'zaman': 80,
#  'koşul': 81,
#  'yapılanmak': 82,
#  'kontrat': 83,
#  'sebep': 84,
#  'süre': 85,
#  'çalışmak': 86,
#  'gider': 87,
#  'müzikhol': 88,
#  'sahne': 89,
#  'Müzik': 90,
#  'tarz': 91,
#  'zor': 92,
#  'kalmak': 93,
#  'daha': 94,
#  'sonra': 95,
#  'ev': 96,
#  'halis': 97,
#  'serbest': 98,
#  'karşılaşmak': 99,
#  'manipülatif': 100,
#  'olay': 101,
#  'dizi': 102,
#  'bulmak': 103,
#  'kendi': 104,
#  'le': 105,
#  'yapmak': 106,
#  'düşlemek': 107,
#  'tersinmek': 108,
#  'i': 109,
#  'koparmak': 110,
#  'şiddet': 111,
#  'do': 112,
#  'gün': 113,
#  'tüm': 114,
#  'yalnız': 115,
#  'kariyer': 116,
#  'güzel': 117,
#  'yerinde': 118,
#  'kezzap': 119,
#  'saldırı': 120,
#  'uğramak': 121,
#  'göz': 122,
#  'kaybetmek': 123,
#  'trajedi': 124,
#  'rağmen': 125,
#  'dönmek': 126,
#  'olağanüstü': 127,
#  'şarkı': 128,
#  'Türkiye': 129,
#  'çap': 130,
#  'Şöhret': 131,
#  'tehdit': 132,
#  'taciz': 133,
#  'seyretmek': 134,
#  'gerilim': 135,
#  'ilişki': 136,
#  'gitmek': 137,
#  'Geller': 138,
#  'deva': 139,
#  'etmek': 140,
#  'korku': 141,
#  'son': 142,
#  'kesinmek': 143,
#  'te': 144,
#  'kurtulmak': 145,
#  'düşünmek': 146,
#  'yolcu': 147,
#  'silâh': 148,
#  'ağır': 149,
#  'yaralamak': 150,
#  'henüz': 151,
#  '30': 152,
#  'yaş': 153,
#  'ölmek': 154,
#  'kurban': 155,
#  'kraliçe': 156,
#  'insan': 157,
#  'kalp': 158,
#  'kazımak': 159,
#  'Dram': 160,
#  'Biyografik': 161,
#  'kirpi': 162,
#  'Sonic': 163,
#  'halka': 164,
#  'yapım': 165,
#  'İnsa': 166,
#  'atılmak': 167,
#  'macera': 168,
#  'konu': 169,
#  'Green': 170,
#  'Hills': 171,
#  'yerleşmek': 172,
#  'tek': 173,
#  'istek': 174,
#  'gerçek': 175,
#  'kahraman': 176,
#  'gerekmek': 177,
#  'özellik': 178,
#  'sahip': 179,
#  'kanıtlamak': 180,
#  'sınav': 181,
#  'Dr': 182,
#  'Robotnik': 183,
#  'ortak': 184,
#  'Knuckes': 185,
#  'medeniyet': 186,
#  'zümrüt': 187,
#  'aramak': 188,
#  'geri': 189,
#  'dönme': 190,
#  'başlamak': 191,
#  'yanlış': 192,
#  'el': 193,
#  'geçmek': 194,
#  'engellemek': 195,
#  'yardım': 196,
#  'Tails': 197,
#  'çıkar': 198,
#  'Animasyon': 199,
#  'Aile': 200,
#  'Macera': 201,
#  'Karanlık': 202,
#  'büyü': 203,
#  'Gellert': 204,
#  'Grindelwald': 205,
#  'kontrol': 206,
#  'elemek': 207,
#  'geçirmek': 208,
#  'hareket': 209,
#  'geçmiş': 210,
#  'bun': 211,
#  'öğrenmek': 212,
#  'profesör': 213,
#  'Albus': 214,
#  'Dumbledore': 215,
#  'önce': 216,
#  'baş': 217,
#  'durmak': 218,
#  'Çalışır': 219,
#  'başarmak': 220,
#  'ara': 221,
#  'cadı': 222,
#  'cesur': 223,
#  'Muggle': 224,
#  'fırın': 225,
#  'oluşmak': 226,
#  'ekip': 227,
#  'yönetim': 228,
#  'Büyüzoolog': 229,
#  'Newt': 230,
#  'Scamander': 231,
#  'A': 232,
#  'emanet': 233,
#  'tehlike': 234,
#  'görev': 235,
#  'üstlenmek': 236,
#  'ekmek': 237,
#  'canavar': 238,
#  'mücadele': 239,
#  'sayı': 240,
#  'Artan': 241,
#  'un': 242,
#  'mürit': 243,
#  'savaşmak': 244,
#  'risk': 245,
#  'karşı': 246,
#  'kadar': 247,
#  'kenar': 248,
#  'beklemek': 249,
#  'Fantastik': 250,
#  'Aykut': 251,
#  'enişte': 252,
#  '2': 253,
#  'sevmek': 254,
#  'arife': 255,
#  'türlü': 256,
#  'bulamak': 257,
#  'hikâye': 258,
#  'Gülşah': 259,
#  'hazırlık': 260,
#  'I': 261,
#  'elinden': 262,
#  'kaçırmak': 263,
#  'karar': 264,
#  'Atabeyoğlu': 265,
#  'nin': 266,
#  'damat': 267,
#  'oldukça': 268,
#  'heyecan': 269,
#  'duru': 270,
#  'plan': 271,
#  'alt': 272,
#  'üst': 273,
#  'eskimek': 274,
#  'Talat': 275,
#  'In': 276,
#  'düğü': 277,
#  'Orta': 278,
#  'çıkmak': 279,
#  'iş': 280,
#  'karışmak': 281,
#  'iyi': 282,
#  'niyet': 283,
#  'saf': 284,
#  'nedeniyle': 285,
#  'açılamak': 286,
#  'belâ': 287,
#  'çalışan': 288,
#  'Mi': 289,
#  'Komedi': 290,
#  'Morbius': 291,
#  'hastalık': 292,
#  'bambaşka': 293,
#  'var': 294,
#  'bili': 295,
#  'Michael': 296,
#  'muzdarip': 297,
#  'nadir': 298,
#  'görü': 299,
#  'kan': 300,
#  'deney': 301,
#  'yöntem': 302,
#  'tedavi': 303,
#  'elektroşok': 304,
#  'terapi': 305,
#  'vampir': 306,
#  'yarasa': 307,
#  'kul': 308,
#  'korkunç': 309,
#  'sonuçlamak': 310,
#  'artık': 311,
#  'hiçbir': 312,
#  'eski': 313,
#  'birçok': 314,
#  'kala': 315,
#  'sürekli': 316,
#  'kana': 317,
#  'ihtiyaç': 318,
#  'ışık': 319,
#  'imkân': 320,
#  'bu': 321,
#  'sorun': 322,
#  'sır': 323,
#  'insanüstü': 324,
#  'Aksiyon': 325,
#  'Kırmız': 326,
#  'ergen': 327,
#  'getirmek': 328,
#  'sıkışmak': 329,
#  'üç': 330,
#  'Mei': 331,
#  'Lee': 332,
#  'odak': 333,
#  'beklenti': 334,
#  'beraberinde': 335,
#  'karmaşmak': 336,
#  '13': 337,
#  'kız': 338,
#  'baskı': 339,
#  'korumak': 340,
#  'Ming': 341,
#  'Uzak': 342,
#  'istemek': 343,
#  'Talih': 344,
#  'hem': 345,
#  'vücut': 346,
#  'değişik': 347,
#  'uğraşmak': 348,
#  'heyecanlanmak': 349,
#  'dev': 350,
#  'panda': 351,
#  '20': 352,
#  'Li': 353,
#  'hal': 354,
#  'lise': 355,
#  'öğrenci': 356,
#  'müzeyyen': 357,
#  'çoğu': 358,
#  'Bekir': 359,
#  'Ebru': 360,
#  'Hazerhan': 361,
#  'Ferdane': 362,
#  'kadir': 363,
#  'de': 364,
#  'arkadaş': 365,
#  'Grub': 366,
#  'geçirir': 367,
#  'bütün': 368,
#  'günah': 369,
#  'paylaşmak': 370,
#  'iletişim': 371,
#  'görmek': 372,
#  'dok': 373,
#  'beri': 374,
#  'haberdar': 375,
#  'kardeş': 376,
#  'ali': 377,
#  'yirmi': 378,
#  'yılmak': 379,
#  'yasak': 380,
#  'hamil': 381,
#  'kalın': 382,
#  'terketmek': 383,
#  'hepsi': 384,
#  'yen': 385,
#  'yarıyıl': 386,
#  'Tati': 387,
#  'fırsat': 388,
#  'tanışmak': 389,
#  'Antalya': 390,
#  'arka': 391,
#  'Sokak': 392,
#  'Yi': 393,
#  'kabul': 394,
#  'dâhil': 395,
#  'iki': 396,
#  'amaç': 397,
#  'birinci': 398,
#  'bol': 399,
#  'götürmek': 400,
#  'Yaşam': 401,
#  'standart': 402,
#  'erişmek': 403,
#  'sağlamak': 404,
#  'diğer': 405,
#  'kesişmek': 406,
#  'ermek': 407,
#  'Trabzon': 408,
#  'Maçka': 409,
#  'terörist': 410,
#  'Mehmet': 411,
#  'çatışmak': 412,
#  'sırasında': 413,
#  'bülbül': 414,
#  'şehit': 415,
#  'astsubay': 416,
#  'kıdem': 417,
#  'başçavuş': 418,
#  'Ferhat': 419,
#  'Gedik': 420,
#  'örümcek': 421,
#  'kimlik': 422,
#  'açık': 423,
#  'vermek': 424,
#  'doktor': 425,
#  'Strange': 426,
#  'ifşa': 427,
#  'halk': 428,
#  'ön': 429,
#  'sermek': 430,
#  'kaos': 431,
#  'Peter': 432,
#  'aynı': 433,
#  'suç': 434,
#  'lanse': 435,
#  'edi': 436,
#  'MJ': 437,
#  'Ned': 438,
#  'olumsuz': 439,
#  'etkilemek': 440,
#  'şahit': 441,
#  'üniversite': 442,
#  'şans': 443,
#  'seyir': 444,
#  'ister': 445,
#  'yakarmak': 446,
#  'on': 447,
#  'nü': 448,
#  'büyümek': 449,
#  'May': 450,
#  'Happy': 451,
#  'hatırlamak': 452,
#  'kişi': 453,
#  'parametre': 454,
#  'The': 455,
#  'batman': 456,
#  'suçlu': 457,
#  'salâ': 458,
#  'Riddler': 459,
#  'isim': 460,
#  'Seri': 461,
#  'katil': 462,
#  'salmak': 463,
#  'Bruce': 464,
#  'Wayne': 465,
#  'Gotham': 466,
#  'City': 467,
#  'karanlık': 468,
#  'sürüklemek': 469,
#  'Gizem': 470,
#  'şehir': 471,
#  'seçkin': 472,
#  'hedef': 473,
#  'diz': 474,
#  'sadist': 475,
#  'hain': 476,
#  'iz': 477,
#  'sürme': 478,
#  'İpuçlarınını': 479,
#  'peşin': 480,
#  'Gide': 481,
#  'yol': 482,
#  'süreç': 483,
#  'Catwoman': 484,
#  'Selina': 485,
#  'Kyle': 486,
#  'penguen': 487,
#  'Oswald': 488,
#  'Cobblepot': 489,
#  'Carmine': 490,
#  'Falcone': 491,
#  'karakter': 492,
#  'kurmak': 493,
#  'maske': 494,
#  'düşürmek': 495,
#  'Ni': 496,
#  'huzur': 497,
#  'kavuşmak': 498,
#  'girişmek': 499,
#  'Polisiye': 500,
#  'Gerilim': 501,
#  'taşımak': 502,
#  'yer': 503,
#  'Sherlock': 504,
#  'kurgu': 505,
#  'dedektif': 506,
#  'rol': 507,
#  'ün': 508,
#  'Wikileaks': 509,
#  'beşinci': 510,
#  'kuvvet': 511,
#  'bilinmez': 512,
#  'doğru': 513,
#  'star': 514,
#  'Trek': 515,
#  'Imitation': 516,
#  'Game': 517,
#  'Enigma': 518,
#  'Benedict': 519,
#  'Cumberbatch': 520,
#  'yönetmek': 521,
#  'Scott': 522,
#  'Derrickson': 523,
#  'kamera': 524,
#  'Arkas': 525,
#  'Sadık': 526,
#  'us': 527,
#  'Wong': 528,
#  'Dilberay': 529,
#  '2019': 530,
#  'veda': 531,
#  'dilber': 532,
#  'aymak': 533,
#  'Kahramanmaraş': 534,
#  'Ta': 535,
#  'sekiz': 536,
#  'çadır': 537,
#  'para': 538,
#  'karşılık': 539,
#  'satmak': 540,
#  'Sahib': 541,
#  'tutku': 542,
#  'Şark': 543,
#  'söylemekti': 544,
#  'yüz': 545,
#  'dayak': 546,
#  'işkence': 547,
#  'çek': 548,
#  'se': 549,
#  'Güç': 550,
#  'adım': 551,
#  'At': 552,
#  'boyunca': 553,
#  'zirve': 554,
#  'dip': 555,
#  'vurmak': 556,
#  'düşmek': 557,
#  'kuyu': 558,
#  'söylemek': 559,
#  'çıktı': 560,
#  'doru': 561,
#  'orman': 562,
#  'kurtarmak': 563,
#  'Karatay': 564,
#  'Alaca': 565,
#  'hayvan': 566,
#  'sirk': 567,
#  'üzerine': 568,
#  'yak': 569,
#  'yı': 570,
#  'geçer': 571,
#  'zeki': 572,
#  'saye': 573,
#  'kurtaran': 574,
#  'sıra': 575,
#  'sürpriz': 576,
#  'kaçar': 577,
#  'Bebek': 578,
#  'şempanze': 579,
#  'Şöbi': 580,
#  '25': 581,
#  'Ge': 582,
#  'gelecek': 583,
#  'geçen': 584,
#  'demek': 585,
#  'Will': 586,
#  'Salas': 587,
#  'Justin': 588,
#  'Timberlake': 589,
#  'hata': 590,
#  'sonuç': 591,
#  'cinayet': 592,
#  'hüküm': 593,
#  'giymek': 594,
#  'hapishane': 595,
#  'sistem': 596,
#  'çökermek': 597,
#  'zira': 598,
#  'rahatlıkla': 599,
#  'Zeng': 600,
#  'sonsuz': 601,
#  'kalarak': 602,
#  'fakir': 603,
#  'üstelik': 604,
#  'eklemek': 605,
#  'Güçs': 606,
#  'üzmek': 607,
#  'sade': 608,
#  'kalabilmek': 609,
#  'dilenmek': 610,
#  'ödünç': 611,
#  'hatta': 612,
#  'bazen': 613,
#  'çalmak': 614,
#  'yoz': 615,
#  'kaldırmak': 616,
#  'başrol': 617,
#  'Döne': 618,
#  'sinema': 619,
#  'yönelmek': 620,
#  'Scarlett': 621,
#  'Johansson': 622,
#  'anmak': 623,
#  'Amanda': 624,
#  'Seyfried': 625,
#  'oyun': 626,
#  'kadro': 627,
#  'Olivia': 628,
#  'Wild': 629,
#  'Alex': 630,
#  'Pettyfer': 631,
#  'Cillian': 632,
#  'Murphy': 633,
#  'Gattaca': 634,
#  'S1m0ne': 635,
#  'Lord': 636,
#  'of': 637,
#  'War': 638,
#  'yazmak': 639,
#  'Truman': 640,
#  'Show': 641,
#  'terminal': 642,
#  'senaryo': 643,
#  'kale': 644,
#  'ala': 645,
#  'Andrew': 646,
#  'Niccol': 647,
#  'proje': 648,
#  'yaratmak': 649,
#  'Bilimkurgu': 650,
#  'edebiyat': 651,
#  'Anastasia': 652,
#  'Steel': 653,
#  'çeki': 654,
#  'Christian': 655,
#  'Grey': 656,
#  'röportaj': 657,
#  'görüşmek': 658,
#  'tavır': 659,
#  'biraz': 660,
#  'mesafe': 661,
#  'yakışık': 662,
#  'Cazibe': 663,
#  'koymak': 664,
#  'çekim': 665,
#  'bırakmak': 666,
#  'fakat': 667,
#  'şe': 668,
#  'Doyum': 669,
#  'nokta': 670,
#  'Ulaş': 671,
#  'seks': 672,
#  'söz': 673,
#  'gizli': 674,
#  'şehvet': 675,
#  'sapmak': 676,
#  'mı': 677,
#  'L': 678,
#  'James': 679,
#  'liste': 680,
#  'ad': 681,
#  'roman': 682,
#  'Uyar': 683,
#  'yönetmen': 684,
#  'sam': 685,
#  'Taylor': 686,
#  'Johnson': 687,
#  'Jamie': 688,
#  'Dornan': 689,
#  'Dakota': 690,
#  'Romantik': 691,
#  'Recep': 692,
#  'İvedik': 693,
#  '6': 694,
#  'Konya': 695,
#  'Kenya': 696,
#  'davet': 697,
#  'kuru': 698,
#  'fasulye': 699,
#  'festival': 700,
#  'çağırılmaktadır': 701,
#  'memnuniyet': 702,
#  'karşılamak': 703,
#  'Nurullah': 704,
#  'yolmak': 705,
#  'yerinmek': 706,
#  'seyahat': 707,
#  'acente': 708,
#  'Arar': 709,
#  'coğrafya': 710,
#  'düşman': 711,
#  'yerli': 712,
#  'kabile': 713,
#  'has': 714,
#  'vahşî': 715,
#  'dünyada': 716,
#  'ayak': 717,
#  'birbiri': 718,
#  'ilginç': 719,
#  'milyoner': 720,
#  'sandık': 721,
#  'kolay': 722,
#  'olmaz': 723,
#  'yeniden': 724,
#  'çift': 725,
#  'barışmak': 726,
#  'bitmek': 727,
#  'şeytan': 728,
#  'yüzleşmek': 729,
#  'kalırken': 730,
#  'öfke': 731,
#  'kıskanç': 732,
#  'Ty': 733,
#  'Hoechlin': 734,
#  'kim': 735,
#  'Basinger': 736,
#  'Marcia': 737,
#  'Gay': 738,
#  'Harden': 739,
#  'Bella': 740,
#  'Heathcote': 741,
#  'Erotik': 742,
#  'Day': 743,
#  'sevi': 744,
#  'kabadayı': 745,
#  'adalet': 746,
#  'duygu': 747,
#  'Cesaret': 748,
#  'merhamet': 749,
#  'haylaz': 750,
#  'bıkmak': 751,
#  'taraf': 752,
#  'köy': 753,
#  'İstanbul': 754,
#  'göndermek': 755,
#  'kahve': 756,
#  'Seyfi': 757,
#  'yanında': 758,
#  'ailemine': 759,
#  'yükselmek': 760,
#  'kaymak': 761,
#  'yazar': 762,
#  'Loretta': 763,
#  'Sage': 764,
#  'inziva': 765,
#  'çekilmek': 766,
#  'Dash': 767,
#  'canlanmak': 768,
#  'adamak': 769,
#  'kapak': 770,
#  'Mode': 771,
#  'popüler': 772,
#  'egzotik': 773,
#  'Hakk': 774,
#  'kitap': 775,
#  'tanıt': 776,
#  'turne': 777,
#  'eksantrik': 778,
#  'milyarder': 779,
#  'antik': 780,
#  'hazine': 781,
#  'Vakit': 782,
#  'ant': 783,
#  'Üzer': 784,
#  'Uygu': 785,
#  'yetki': 786,
#  'kurtulup': 787,
#  'şeytanî': 788,
#  'bulunmak': 789,
#  'Yüzük': 790,
#  'hükümet': 791,
#  'yakalamak': 792,
#  'devlet': 793,
#  'Eggman': 794,
#  'kasaba': 795,
#  'şerif': 796,
#  'Tom': 797,
#  'Wachowski': 798,
#  'kaçmak': 799,
#  'kuzey': 800,
#  'öldürmek': 801,
#  'intikam': 802,
#  'Viking': 803,
#  'prens': 804,
#  'kral': 805,
#  'Aurvandil': 806,
#  'imparator': 807,
#  'oğul': 808,
#  'Amleth': 809,
#  'devretmek': 810,
#  'üveymek': 811,
#  'Fjölnir': 812,
#  'taht': 813,
#  'amca': 814,
#  'Gudrun': 815,
#  'U': 816,
#  'Görür': 817,
#  'kurtaracağına': 818,
#  'yem': 819,
#  'Slav': 820,
#  'akın': 821,
#  'savaşçı': 822,
#  'Olur': 823,
#  'kâhin': 824,
#  'tutmak': 825,
#  'Tarihi': 826,
#  'Dune': 827,
#  'çöl': 828,
#  'gezegen': 829,
#  'Arrakis': 830,
#  'Paul': 831,
#  'Atreides': 832,
#  'galâksi': 833,
#  'fark': 834,
#  'rakip': 835,
#  'feodal': 836,
#  'çok': 837,
#  'değerli': 838,
#  'kaynak': 839,
#  'üretmek': 840,
#  'asil': 841,
#  'dere': 842,
#  'talep': 843,
#  'baharat': 844,
#  'veri': 845,
#  'Kaynak': 846,
#  'yük': 847,
#  'bilinç': 848,
#  'Uz': 849,
#  'Sunar': 850,
#  'ciddi': 851,
#  'yanmak': 852,
#  'etki': 853,
#  'ayrı': 854,
#  'yıldızlararası': 855,
#  'gezinmek': 856,
#  'tır': 857,
#  'Harkonen': 858,
#  'tuzak': 859,
#  'darmadağın': 860,
#  'olarak': 861,
#  'firarî': 862,
#  'kazanmak': 863,
#  'isyan': 864,
#  'evre': 865,
#  'ihtimalî': 866,
#  'yakalayacaktır': 867,
#  'Frank': 868,
#  'Herbert': 869,
#  '1965': 870,
#  'televizyon': 871,
#  'beyaz': 872,
#  'perde': 873,
#  'Hak': 874,
#  'Legendary': 875,
#  'Entertainment': 876,
#  'uyaramanın': 877,
#  'koltuk': 878,
#  'Arrival': 879,
#  'Sicario': 880,
#  'Blade': 881,
#  'Runner': 882,
#  '2049': 883,
#  'damga': 884,
#  'Oscar': 885,
#  'Denis': 886,
#  'Villeneuve': 887,
#  'oturmak': 888,
#  'Eric': 889,
#  'Roth': 890,
#  'Thomas': 891,
#  'Tull': 892,
#  'Mary': 893,
#  'Parent': 894,
#  'Cale': 895,
#  'Boyter': 896,
#  'hız': 897,
#  '9': 898,
#  'Dominic': 899,
#  'Toretto': 900,
#  'nun': 901,
#  'Brian': 902,
#  'Letty': 903,
#  'Sakin': 904,
#  'kurtulamaz': 905,
#  'siber': 906,
#  'Cipher': 907,
#  'terk': 908,
#  'Jakob': 909,
#  'kalır': 910,
#  'lider': 911,
#  'yıkmak': 912,
#  'Venom': 913,
#  'organizma': 914,
#  'Eddie': 915,
#  'Brock': 916,
#  'infaz': 917,
#  'Cletus': 918,
#  'Kasady': 919,
#  'Shriek': 920,
#  'alışmak': 921,
#  'günü': 922,
#  'kötü': 923,
#  'adam': 924,
#  'dövmek': 925,
#  'muazzam': 926,
#  'açlık': 927,
#  'tatmin': 928,
#  'gazete': 929,
#  'Alev': 930,
#  'herkes': 931,
#  'şey': 932,
#  'şekil': 933,
#  'yetişmek': 934,
#  'dört': 935,
#  'duvar': 936,
#  'geçiren': 937,
#  'eğitim': 938,
#  'alır': 939,
#  'saklamak': 940,
#  'kalacaktır': 941,
#  'Korku': 942,
#  'çılgın': 943,
#  'parti': 944,
#  'kaşımak': 945,
#  'delişmen': 946,
#  'karizmatik': 947,
#  'Jack': 948,
#  'tüccar': 949,
#  'Joy': 950,
#  'Mcnally': 951,
#  'Las': 952,
#  'Vegas': 953,
#  'tantana': 954,
#  'haftasonu': 955,
#  'Fuller': 956,
#  'tesadüfi': 957,
#  'şen': 958,
#  'Hayal': 959,
#  'meyal': 960,
#  'an': 961,
#  'Hatıra': 962,
#  'tatil': 963,
#  'New': 964,
#  'York': 965,
#  'Lu': 966,
#  'hissetmek': 967,
#  'stil': 968,
#  'imza': 969,
#  'atmak': 970,
#  'Bilir': 971,
#  'herşey': 972,
#  'bura': 973,
#  'kumarhane': 974,
#  'aşırı': 975,
#  'merkez': 976,
#  'cinsiyet': 977,
#  'iddia': 978,
#  'glâdyatör': 979,
#  'saadet': 980,
#  'sürmek': 981,
#  'Ganimet': 982,
#  'ulaşmak': 983,
#  'ya': 984,
#  'hararet': 985,
#  'kıvıl': 986,
#  'birgün': 987,
#  'sıçramak': 988,
#  'sahte': 989,
#  'şaşırmak': 990,
#  'soru': 991,
#  'cevap': 992,
#  'izlemek': 993,
#  'bul': 994,
#  'olacaksınız': 995,
#  'Chris': 996,
#  'Evans': 997,
#  'Florida': 998,
#  'kır': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 27754

# %%
import numpy as np

# %%
film_sayisi = len(clean)
vocab_size = len(word2idx)

# %%
filmler = np.zeros((film_sayisi, vocab_size))

# %%
filmler.shape
# Out:
# (5261, 27754)

# %%
for i, cell in enumerate(clean):
    words = cell.split()
    for word in words:
        wordIndex = word2idx[word]
        filmler[i][wordIndex] += 1

# %%
filmler[7][:10]
# Out:
# array([0., 0., 0., 0., 2., 0., 1., 2., 0., 0.])

# %%
doc_frequencies = {}

# %%
# 1 - 5 dk sürebilir 
for word in word2idx:
    doc_count = 0
    for film in clean:
        if word in film:
            doc_count += 1
    
    doc_frequencies[word] = doc_count

# %%
sorted_frequencies = sorted(doc_frequencies, key=doc_frequencies.get, reverse=True)

# %%
for word in sorted_frequencies[0:10]:
    print(word, doc_frequencies[word])
# Out:
# i 5261
# l 5261
# o 5259
# ak 5246
# ek 5239
# an 5228
# er 5214
# ü 5191
# bi 5177
# ya 5145

# %%
for word in sorted_frequencies[150:160]:
    print(word, doc_frequencies[word])
# Out:
# ala 1636
# öz 1623
# alış 1622
# L 1609
# yol 1598
# rol 1590
# iki 1570
# vi 1570
# kat 1564
# yem 1560

# %%
for word in sorted_frequencies[-10:]:
    print(word, doc_frequencies[word])
# Out:
# Daddy 1
# menü 1
# hindi 1
# kaçırıldığında 1
# labaratuarla 1
# Labaratuarda 1
# 1621 1
# Peluchonneau 1
# şairane 1
# bitecekmiş 1

# %%
# 1 - 5 dk sürebilir
filmler_tf_idf = np.zeros((film_sayisi, vocab_size))
film_sayisi = len(clean)

for i, film in enumerate(filmler):
    if i % 1000 == 0:
        print(f"{i} inci film işleniyor...")
    for j, tf in enumerate(film):
        idf = 0
        if tf > 0:
            idf = np.log(film_sayisi / (doc_frequencies[idx2word[j]] + 1)) + 1
        tf_idf_score = tf * idf
        filmler_tf_idf[i][j] = tf_idf_score
# Out:
# 0 inci film işleniyor...
# 1000 inci film işleniyor...
# 2000 inci film işleniyor...
# 3000 inci film işleniyor...
# 4000 inci film işleniyor...
# 5000 inci film işleniyor...

# %%
print(filmler_tf_idf[0][:10])
print(filmler[0][:10])
# Out:
# [15.91727698  5.6762561   2.64346401  3.71300448  2.00038019 81.81782041
#   7.50567832  7.43327815  9.68137717  1.43536991]
# [ 2.  1.  1.  1.  2. 10.  4.  4.  2.  1.]

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def film_2_str(row_index):
    film = df.iloc[row_index]
    adi = film['film adi']
    turu = film['tur']
    ozet = film['ozet ve detaylar']
    if len(ozet) > 150:
        ozet = ozet[:150] + "..."

    return f"Film adı: {adi} \nTürü: {turu} \nÖzeti: {ozet}"

# %%
print(film_2_str(0))
# Out:
# Film adı: Bergen
# Türü: ['Dram', 'Biyografik']
# Özeti: Arabeskin unutulmayan kadın seslerinden biri olan Bergen'in hayatını anlatan filmde, Bergen olarak bilinen Belgin'in Ankara'dan Adana'ya, oradan da ya...

# %%
def most_similar_films(film_adi, benzer_film_sayisi):
    film_indexi = df[df["film adi"] == film_adi].index[0]
    print("Aranan Film:")
    print(film_2_str(film_indexi))
    print()
    print("* " * 30)
    print()

    benzerlikler = []
    sorgu_film = filmler_tf_idf[film_indexi]
    for vec in filmler_tf_idf:
        benzerlik = cos_sim(sorgu_film, vec)
        benzerlikler.append(benzerlik)
    
    en_benzer_film_indexleri = (- np.array(benzerlikler)).argsort()[:benzer_film_sayisi + 1]
    print("Benzer Filmler:\n")
    for i, film_idx in enumerate(en_benzer_film_indexleri[1:]):
        print(str(i+1) + ") " + film_2_str(film_idx))
        print()
        print("- " * 20)
        print()

# %%
df.iloc[350:360]["film adi"]
# Out:
# 350                               Avukat
# 351                        Sevginin Gücü
# 352                         300 Spartalı
# 353              Başlat Ready Player One
# 354                  Kolonya Cumhuriyeti
# 355                               Şantaj
# 356                               Eşkıya
# 357                           Can Dostum
# 358                                 Thor
# 359    Fakat Müzeyyen Bu Derin Bir Tutku
# Name: film adi, dtype: object

# %%
most_similar_films("Thor", 3)
# Out:
# Aranan Film:
# Film adı: Thor
# Türü: ['Aksiyon', 'Fantastik', 'Macera']
# Özeti: Efsanevi Thor macerası, Marvel Evreni’nden, Asgard’ın mistik atmosferine kadar uzanıyor. “Thor” yalnız bir adamın destansı yolculuğunun, tahtın veliah...
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# Benzer Filmler:
#
# 1) Film adı: Thor: Karanlık Dünya
# Türü: ['Aksiyon', 'Fantastik', 'Macera']
# Özeti: Tanrıların dünyanın ötesindeki mücadelesi devam ediyor. İlk filmde babası tarafından güçleri elinden alınarak dünyaya sürgün edilen Thor, kendisini ye...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 2) Film adı: Thor: Ragnarok
# Türü: ['Aksiyon', 'Bilimkurgu']
# Özeti: Thor serisinin 2017 yılında izleyiciyle buluşacak olan üçüncü filminde, yaklaşmakta olan Norse kıyametine tanık olacağız. Asgard'tan uzakta, evrenin ö...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 3) Film adı: Yenilmezler
# Türü: ['Aksiyon', 'Macera', 'Bilimkurgu']
# Özeti: SHIELD adıyla tanınan uluslararası barış örgütünün başındaki isim Nick Fury, tüm dünyanın güvenliğine karşı büyük bir tehdit oluşturan düşmanla karşı ...
#
# - - - - - - - - - - - - - - - - - - - -
